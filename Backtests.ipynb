# %%
from Backtest import Backtest as BT

# %%
options = {'ticker': 'BTC-USD',
           'period': '1y',
           'interval': '1d',
           'risk': 0.75,
           'ta': [
               {'name': 'MACD', 'fast': 15, 'slow': 30, 'smooth': 10},
               {'name': 'WTLB', 'clength': 10, 'alength': 21}
           ]
           }

# %%
my_backtest = BT(options)
my_backtest.plot_strat()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
my_backtest.portfolio.current_balance
# Out:
# 14522.320836019782

# %%
options2 = {'ticker': 'ETH-USD',
           'period': '1y',
           'interval': '1d',
           'risk': 0.75,
           'ta': [
               {'name': 'MACD', 'fast': 15, 'slow': 30, 'smooth': 10},
               {'name': 'WTLB', 'clength': 10, 'alength': 21}
           ]
           }

my_backtest2 = BT(options2, portfolio=my_backtest.portfolio)
my_backtest2.plot_strat()
# Out:
# [*********************100%***********************]  1 of 1 completed
